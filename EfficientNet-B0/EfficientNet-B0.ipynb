# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.math import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, DepthwiseConv2D, Reshape, Multiply
import keras_tuner as kt
import os
import random
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Define hyperparameters
hyperparameters = {
    'learning_rate': 0.001,
    'batch_size': 8,
    'epochs': 50,
    'optimizer': 'adam',
    'loss_function': 'sparse_categorical_crossentropy',
    'image_size': (128, 128),
    'num_classes': 4,
    'data_augmentation': True,
}

# TensorBoard Logging
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# Create the TensorBoard callback
tensorboard_callback = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
)

# %%
# --- UPDATED PATHS ---
train_csv_path = "C:/Users/matko/Desktop/data_h_c_s_a/spectograms/train.csv"
train_img_dir = "C:/Users/matko/Desktop/data_h_c_s_a/spectograms/train"

# Load the dataset
train = pd.read_csv(train_csv_path)

# Split into train and validation sets
train, valid = train_test_split(
    train,
    test_size=0.2,         # 20% for validation
    stratify=train["category"],  # keep class distribution
    random_state=42
)

# %%
# Check the shape of the dataset
print("Train shape:", train.shape)
print("Valid shape:", valid.shape)

# Plot the distribution of ship categories
ship_categories = {0: 'Synthetize', 1: 'Annonymise', 2: 'Cloned', 3: 'Human'}
sns.countplot(x=train["category"].map(ship_categories))
plt.title("Distribution of Sound Categories (Train)")
plt.show()

sns.countplot(x=valid["category"].map(ship_categories))
plt.title("Distribution of Sound Categories (Valid)")
plt.show()
# Out:
# Train shape: (36128, 2)
# Valid shape: (9032, 2)

# %%
def load_and_preprocess_images(df, img_dir):
    images = []
    for img_name in df["image"]:  # Use the correct column name for image filenames
        img_path = os.path.join(img_dir, img_name)
        img = tf.keras.utils.load_img(img_path, color_mode='grayscale')  # No target_size needed
        imgarr = tf.keras.utils.img_to_array(img) / 255.0
        images.append(imgarr)
    return np.asarray(images)

# Prepare data
X_train = load_and_preprocess_images(train, train_img_dir)
X_valid = load_and_preprocess_images(valid, train_img_dir)

# %%
def swish(x):
    return x * tf.nn.sigmoid(x)

def mb_conv_block(x, filters_in, filters_out, expand_ratio=1, stride=1, se_ratio=0.25):
    inputs = x  # Save for residual connection
    channels = filters_in * expand_ratio
    if expand_ratio != 1:
        x = Conv2D(channels, 1, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation(swish)(x)
    
    x = DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    
    if se_ratio:
        se_channels = max(1, int(filters_in * se_ratio))
        se = GlobalAveragePooling2D()(x)
        se = Reshape((1, 1, channels))(se)
        se = Conv2D(se_channels, 1, padding='same', activation='relu')(se)
        se = Conv2D(channels, 1, padding='same', activation='sigmoid')(se)
        x = Multiply()([x, se])
    
    x = Conv2D(filters_out, 1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    
    if stride == 1 and filters_in == filters_out:
        x = Add()([x, inputs])
    
    return x

def build_lite_efficientnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    
    # Stem
    x = Conv2D(16, 3, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    
    # MBConv blocks (scaled down version)
    blocks = [
        # expand, in_ch, out_ch, stride, se_ratio, repeats
        (1, 16, 16, 1, 0.25, 1),
        (6, 16, 24, 2, 0.25, 2),
        (6, 24, 40, 2, 0.25, 2),
        (6, 40, 80, 2, 0.25, 3),
        (6, 80, 112, 1, 0.25, 3),
        (6, 112, 192, 2, 0.25, 4),
        (6, 192, 320, 1, 0.25, 1)
    ]
    
    for expand, in_ch, out_ch, stride, se_ratio, repeats in blocks:
        for i in range(repeats):
            if i > 0:  # Only first block in sequence uses stride
                stride = 1
            x = mb_conv_block(
                x, 
                filters_in=in_ch, 
                filters_out=out_ch,
                expand_ratio=expand,
                stride=stride,
                se_ratio=se_ratio
            )
            in_ch = out_ch  # Update input channels for next block
    
    # Head
    x = Conv2D(640, 1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    x = GlobalAveragePooling2D()(x)
    
    # Output
    outputs = Dense(num_classes, activation='softmax')(x)
    
    return Model(inputs, outputs)

# %%
# Extract labels
y_train = train["category"].values
y_valid = valid["category"].values

# %%
# EarlyStopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True,
    verbose=1
)

# %%
# Define tuner directory for Keras Tuner results
tuner_dir = "tuner_dir"

def build_tunable_lite_efficientnet(hp):
    input_shape = (*hyperparameters['image_size'], 1)
    num_classes = hyperparameters['num_classes']

    inputs = Input(shape=input_shape)
    x = Conv2D(
        hp.Int('stem_filters', min_value=8, max_value=32, step=8),
        3, strides=2, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)

    # Use a single tunable MBConv block for demonstration (expand as needed)
    expand = hp.Choice('expand_ratio', [1, 3, 6])
    in_ch = hp.Int('in_ch', 8, 32, step=8)
    out_ch = hp.Int('out_ch', 16, 48, step=8)
    stride = 1
    se_ratio = 0.25

    x = mb_conv_block(
        x,
        filters_in=in_ch,
        filters_out=out_ch,
        expand_ratio=expand,
        stride=stride,
        se_ratio=se_ratio
    )

    x = Conv2D(
        hp.Int('head_filters', min_value=64, max_value=256, step=64),
        1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation(swish)(x)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)

    lr = hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=hyperparameters['loss_function'],
        metrics=['accuracy']
    )
    return model

tuner = kt.Hyperband(
    build_tunable_lite_efficientnet,
    objective='val_accuracy',
    max_epochs=10,
    factor=3,
    directory=tuner_dir,
    project_name='lite_effnet_tuning'
)

stop_early = EarlyStopping(monitor='val_loss', patience=3)
# Out:
# Reloading Tuner from kt_lite_effnet_results\lite_effnet_tuning\tuner0.json

# %%
tuner.search(
    X_train, y_train,
    epochs=10,
    validation_data=(X_valid, y_valid),
    callbacks=[stop_early]
)
# Out:
# Trial 23 Complete [00h 06m 38s]
# val_accuracy: 0.8631532192230225
#
# Best val_accuracy So Far: 0.8631532192230225
# Total elapsed time: 00h 57m 02s

# %%
# Get the best model and retrain
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.hypermodel.build(best_hp)

history = best_model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=hyperparameters['batch_size'],
    epochs=hyperparameters['epochs'],
    callbacks=[tensorboard_callback, early_stopping]
)

# Save the best model
best_model.save('best_lite_effnet_tuned.h5.keras')
# Out:
# Epoch 1/50
# 4516/4516 [==============================] - 70s 13ms/step - loss: 0.4499 - accuracy: 0.8019 - val_loss: 7.6370 - val_accuracy: 0.3026
# Epoch 2/50
# 4516/4516 [==============================] - 59s 13ms/step - loss: 0.2935 - accuracy: 0.8586 - val_loss: 0.2901 - val_accuracy: 0.8485
# Epoch 3/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.2713 - accuracy: 0.8642 - val_loss: 2.9578 - val_accuracy: 0.4249
# Epoch 4/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.2536 - accuracy: 0.8703 - val_loss: 0.2989 - val_accuracy: 0.8423
# Epoch 5/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.2419 - accuracy: 0.8732 - val_loss: 0.7184 - val_accuracy: 0.7003
# Epoch 6/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.2373 - accuracy: 0.8726 - val_loss: 2.4736 - val_accuracy: 0.5378
# Epoch 7/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.2353 - accuracy: 0.8747 - val_loss: 0.8227 - val_accuracy: 0.7324
# Epoch 8/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.2274 - accuracy: 0.8772 - val_loss: 2.8025 - val_accuracy: 0.5552
# Epoch 9/50
# 4516/4516 [==============================] - 55s 12ms/step - loss: 0.2260 - accuracy: 0.8777 - val_loss: 0.2118 - val_accuracy: 0.8810
# Epoch 10/50
# 4516/4516 [==============================] - 55s 12ms/step - loss: 0.2207 - accuracy: 0.8785 - val_loss: 0.3843 - val_accuracy: 0.8189
# Epoch 11/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.2190 - accuracy: 0.8792 - val_loss: 3.9686 - val_accuracy: 0.3883
# Epoch 12/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.2180 - accuracy: 0.8795 - val_loss: 0.2669 - val_accuracy: 0.8592
# Epoch 13/50
# 4516/4516 [==============================] - 58s 13ms/step - loss: 0.2124 - accuracy: 0.8824 - val_loss: 3.9474 - val_accuracy: 0.4130
# Epoch 14/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.2109 - accuracy: 0.8823 - val_loss: 0.2488 - val_accuracy: 0.8703
# Epoch 15/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.2087 - accuracy: 0.8802 - val_loss: 0.1892 - val_accuracy: 0.8921
# Epoch 16/50
# 4516/4516 [==============================] - 56s 13ms/step - loss: 0.2084 - accuracy: 0.8835 - val_loss: 0.5270 - val_accuracy: 0.8157
# Epoch 17/50
# 4516/4516 [==============================] - 55s 12ms/step - loss: 0.2050 - accuracy: 0.8812 - val_loss: 10.1619 - val_accuracy: 0.2974
# Epoch 18/50
# 4516/4516 [==============================] - 55s 12ms/step - loss: 0.2038 - accuracy: 0.8823 - val_loss: 0.2297 - val_accuracy: 0.8836
# Epoch 19/50
# 4516/4516 [==============================] - 54s 12ms/step - loss: 0.1988 - accuracy: 0.8849 - val_loss: 0.1858 - val_accuracy: 0.8893
# Epoch 20/50
# 4516/4516 [==============================] - 54s 12ms/step - loss: 0.1996 - accuracy: 0.8846 - val_loss: 0.3509 - val_accuracy: 0.8360
# Epoch 21/50
# 4516/4516 [==============================] - 53s 12ms/step - loss: 0.1981 - accuracy: 0.8849 - val_loss: 0.4393 - val_accuracy: 0.8702
# Epoch 22/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.1971 - accuracy: 0.8838 - val_loss: 0.4401 - val_accuracy: 0.8541
# Epoch 23/50
# 4516/4516 [==============================] - 55s 12ms/step - loss: 0.1931 - accuracy: 0.8865 - val_loss: 2.1399 - val_accuracy: 0.8576
# Epoch 24/50
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.1927 - accuracy: 0.8852 - val_loss: 0.1980 - val_accuracy: 0.8860
# Epoch 25/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.1929 - accuracy: 0.8859 - val_loss: 4.2472 - val_accuracy: 0.5601
# Epoch 26/50
# 4516/4516 [==============================] - 57s 13ms/step - loss: 0.1921 - accuracy: 0.8871 - val_loss: 1.1056 - val_accuracy: 0.6592
# Epoch 27/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1906 - accuracy: 0.8859Restoring model weights from the end of the best epoch: 19.
# 4516/4516 [==============================] - 56s 12ms/step - loss: 0.1906 - accuracy: 0.8859 - val_loss: 0.2857 - val_accuracy: 0.8360
# Epoch 27: early stopping

# %%
# Build model
model = build_lite_efficientnet(
    input_shape=(*hyperparameters['image_size'], 1),
    num_classes=hyperparameters['num_classes']
)

model.compile(
    optimizer=hyperparameters['optimizer'],
    loss=hyperparameters['loss_function'],
    metrics=['accuracy']
)

model.summary()

# Update checkpoint name
checkpoint = ModelCheckpoint('best_lite_effnet.h5.keras', 
                            monitor='val_accuracy', 
                            save_best_only=True, 
                            mode='max', 
                            verbose=1)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 16)   144         ['input_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_4[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 64, 64, 16)  144         ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 16)  64          ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_5[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 16)          0           ['activation_4[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 16)     0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  conv2d_6 (Conv2D)              (None, 1, 1, 4)      68          ['reshape_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 1, 1, 16)     80          ['conv2d_6[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 16)   0           ['activation_4[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 16)   256         ['multiply_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 64, 16)   0           ['batch_normalization_6[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 96)   1536        ['add_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 96)  384         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 96)   0           ['batch_normalization_7[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 32, 32, 96)  864         ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 96)  384         ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 96)   0           ['batch_normalization_8[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 96)          0           ['activation_6[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 96)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  conv2d_10 (Conv2D)             (None, 1, 1, 4)      388         ['reshape_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 1, 1, 96)     480         ['conv2d_10[0][0]']
#
#  multiply_2 (Multiply)          (None, 32, 32, 96)   0           ['activation_6[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 24)   2304        ['multiply_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 24)  96          ['conv2d_12[0][0]']
#  rmalization)
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 144)  3456        ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 144)  576        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 32, 32, 144)  0           ['batch_normalization_10[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 32, 32, 144)  1296       ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 144)  576        ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 32, 32, 144)  0           ['batch_normalization_11[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 144)         0           ['activation_8[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 144)    0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  conv2d_14 (Conv2D)             (None, 1, 1, 6)      870         ['reshape_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 1, 1, 144)    1008        ['conv2d_14[0][0]']
#
#  multiply_3 (Multiply)          (None, 32, 32, 144)  0           ['activation_8[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 24)   3456        ['multiply_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 24)  96          ['conv2d_16[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 32, 32, 24)   0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 144)  3456        ['add_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 144)  576        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 32, 32, 144)  0           ['batch_normalization_13[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 16, 16, 144)  1296       ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 144)  576        ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 144)  0           ['batch_normalization_14[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 144)         0           ['activation_10[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 144)    0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  conv2d_18 (Conv2D)             (None, 1, 1, 6)      870         ['reshape_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 1, 1, 144)    1008        ['conv2d_18[0][0]']
#
#  multiply_4 (Multiply)          (None, 16, 16, 144)  0           ['activation_10[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 40)   5760        ['multiply_4[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 40)  160         ['conv2d_20[0][0]']
#  ormalization)
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 240)  9600        ['batch_normalization_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 240)  960        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 240)  0           ['batch_normalization_16[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 16, 16, 240)  2160       ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 240)  960        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 16, 16, 240)  0           ['batch_normalization_17[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 240)         0           ['activation_12[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 240)    0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  conv2d_22 (Conv2D)             (None, 1, 1, 10)     2410        ['reshape_5[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 1, 1, 240)    2640        ['conv2d_22[0][0]']
#
#  multiply_5 (Multiply)          (None, 16, 16, 240)  0           ['activation_12[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 40)   9600        ['multiply_5[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 40)  160         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 16, 16, 40)   0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 240)  9600        ['add_3[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 240)  960        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 16, 16, 240)  0           ['batch_normalization_19[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 8, 8, 240)   2160        ['activation_13[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 240)   960         ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 8, 8, 240)    0           ['batch_normalization_20[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 240)         0           ['activation_14[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 240)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  conv2d_26 (Conv2D)             (None, 1, 1, 10)     2410        ['reshape_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 1, 1, 240)    2640        ['conv2d_26[0][0]']
#
#  multiply_6 (Multiply)          (None, 8, 8, 240)    0           ['activation_14[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 80)     19200       ['multiply_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 80)    320         ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 8, 8, 480)    38400       ['batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 480)   1920        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_22[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 8, 8, 480)   4320        ['activation_15[0][0]']
#  onv2D)
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 480)   1920        ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_23[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 480)         0           ['activation_16[0][0]']
#  obalAveragePooling2D)
#
#  reshape_7 (Reshape)            (None, 1, 1, 480)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  conv2d_30 (Conv2D)             (None, 1, 1, 20)     9620        ['reshape_7[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 1, 1, 480)    10080       ['conv2d_30[0][0]']
#
#  multiply_7 (Multiply)          (None, 8, 8, 480)    0           ['activation_16[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 80)     38400       ['multiply_7[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 80)    320         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 8, 8, 80)     0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 480)    38400       ['add_4[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 480)   1920        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_25[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 8, 8, 480)   4320        ['activation_17[0][0]']
#  onv2D)
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 480)   1920        ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_26[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 480)         0           ['activation_18[0][0]']
#  obalAveragePooling2D)
#
#  reshape_8 (Reshape)            (None, 1, 1, 480)    0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  conv2d_34 (Conv2D)             (None, 1, 1, 20)     9620        ['reshape_8[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 1, 1, 480)    10080       ['conv2d_34[0][0]']
#
#  multiply_8 (Multiply)          (None, 8, 8, 480)    0           ['activation_18[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 80)     38400       ['multiply_8[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 80)    320         ['conv2d_36[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 8, 8, 80)     0           ['batch_normalization_27[0][0]',
#                                                                   'add_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 480)    38400       ['add_5[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 480)   1920        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_28[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 8, 8, 480)   4320        ['activation_19[0][0]']
#  onv2D)
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 480)   1920        ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 8, 8, 480)    0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_9 (Gl  (None, 480)         0           ['activation_20[0][0]']
#  obalAveragePooling2D)
#
#  reshape_9 (Reshape)            (None, 1, 1, 480)    0           ['global_average_pooling2d_9[0][0
#                                                                  ]']
#
#  conv2d_38 (Conv2D)             (None, 1, 1, 20)     9620        ['reshape_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 1, 1, 480)    10080       ['conv2d_38[0][0]']
#
#  multiply_9 (Multiply)          (None, 8, 8, 480)    0           ['activation_20[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 112)    53760       ['multiply_9[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 112)   448         ['conv2d_40[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 672)    75264       ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 672)   2688        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 672)    0           ['batch_normalization_31[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 8, 8, 672)   6048        ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 672)   2688        ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 672)    0           ['batch_normalization_32[0][0]']
#
#  global_average_pooling2d_10 (G  (None, 672)         0           ['activation_22[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_10 (Reshape)           (None, 1, 1, 672)    0           ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  conv2d_42 (Conv2D)             (None, 1, 1, 28)     18844       ['reshape_10[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 1, 1, 672)    19488       ['conv2d_42[0][0]']
#
#  multiply_10 (Multiply)         (None, 8, 8, 672)    0           ['activation_22[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 112)    75264       ['multiply_10[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 112)   448         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 112)    0           ['batch_normalization_33[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 672)    75264       ['add_6[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 672)   2688        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 8, 8, 672)    0           ['batch_normalization_34[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 8, 8, 672)   6048        ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 672)   2688        ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 8, 8, 672)    0           ['batch_normalization_35[0][0]']
#
#  global_average_pooling2d_11 (G  (None, 672)         0           ['activation_24[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_11 (Reshape)           (None, 1, 1, 672)    0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  conv2d_46 (Conv2D)             (None, 1, 1, 28)     18844       ['reshape_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 1, 1, 672)    19488       ['conv2d_46[0][0]']
#
#  multiply_11 (Multiply)         (None, 8, 8, 672)    0           ['activation_24[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 8, 8, 112)    75264       ['multiply_11[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 8, 112)   448         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 112)    0           ['batch_normalization_36[0][0]',
#                                                                   'add_6[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 8, 8, 672)    75264       ['add_7[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 8, 672)   2688        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 8, 8, 672)    0           ['batch_normalization_37[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 4, 4, 672)   6048        ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 4, 4, 672)   2688        ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 4, 4, 672)    0           ['batch_normalization_38[0][0]']
#
#  global_average_pooling2d_12 (G  (None, 672)         0           ['activation_26[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_12 (Reshape)           (None, 1, 1, 672)    0           ['global_average_pooling2d_12[0][
#                                                                  0]']
#
#  conv2d_50 (Conv2D)             (None, 1, 1, 28)     18844       ['reshape_12[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 1, 1, 672)    19488       ['conv2d_50[0][0]']
#
#  multiply_12 (Multiply)         (None, 4, 4, 672)    0           ['activation_26[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 4, 4, 192)    129024      ['multiply_12[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 192)   768         ['conv2d_52[0][0]']
#  ormalization)
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 1152)   221184      ['batch_normalization_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 1152)  4608        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_40[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 4, 4, 1152)  10368       ['activation_27[0][0]']
#  Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 1152)  4608        ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_41[0][0]']
#
#  global_average_pooling2d_13 (G  (None, 1152)        0           ['activation_28[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_13 (Reshape)           (None, 1, 1, 1152)   0           ['global_average_pooling2d_13[0][
#                                                                  0]']
#
#  conv2d_54 (Conv2D)             (None, 1, 1, 48)     55344       ['reshape_13[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 1, 1, 1152)   56448       ['conv2d_54[0][0]']
#
#  multiply_13 (Multiply)         (None, 4, 4, 1152)   0           ['activation_28[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 192)    221184      ['multiply_13[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 4, 4, 192)   768         ['conv2d_56[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 4, 4, 192)    0           ['batch_normalization_42[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 1152)   221184      ['add_8[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 4, 4, 1152)  4608        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_43[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 4, 4, 1152)  10368       ['activation_29[0][0]']
#  Conv2D)
#
#  batch_normalization_44 (BatchN  (None, 4, 4, 1152)  4608        ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_44[0][0]']
#
#  global_average_pooling2d_14 (G  (None, 1152)        0           ['activation_30[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_14 (Reshape)           (None, 1, 1, 1152)   0           ['global_average_pooling2d_14[0][
#                                                                  0]']
#
#  conv2d_58 (Conv2D)             (None, 1, 1, 48)     55344       ['reshape_14[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 1, 1, 1152)   56448       ['conv2d_58[0][0]']
#
#  multiply_14 (Multiply)         (None, 4, 4, 1152)   0           ['activation_30[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 192)    221184      ['multiply_14[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 4, 4, 192)   768         ['conv2d_60[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 4, 4, 192)    0           ['batch_normalization_45[0][0]',
#                                                                   'add_8[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 4, 4, 1152)   221184      ['add_9[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 4, 4, 1152)  4608        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_46[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 4, 4, 1152)  10368       ['activation_31[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 4, 4, 1152)  4608        ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_47[0][0]']
#
#  global_average_pooling2d_15 (G  (None, 1152)        0           ['activation_32[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_15 (Reshape)           (None, 1, 1, 1152)   0           ['global_average_pooling2d_15[0][
#                                                                  0]']
#
#  conv2d_62 (Conv2D)             (None, 1, 1, 48)     55344       ['reshape_15[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 1, 1, 1152)   56448       ['conv2d_62[0][0]']
#
#  multiply_15 (Multiply)         (None, 4, 4, 1152)   0           ['activation_32[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 4, 4, 192)    221184      ['multiply_15[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 4, 4, 192)   768         ['conv2d_64[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 4, 4, 192)    0           ['batch_normalization_48[0][0]',
#                                                                   'add_9[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 4, 4, 1152)   221184      ['add_10[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 4, 4, 1152)  4608        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_49[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (None, 4, 4, 1152)  10368       ['activation_33[0][0]']
#  Conv2D)
#
#  batch_normalization_50 (BatchN  (None, 4, 4, 1152)  4608        ['depthwise_conv2d_16[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 4, 4, 1152)   0           ['batch_normalization_50[0][0]']
#
#  global_average_pooling2d_16 (G  (None, 1152)        0           ['activation_34[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_16 (Reshape)           (None, 1, 1, 1152)   0           ['global_average_pooling2d_16[0][
#                                                                  0]']
#
#  conv2d_66 (Conv2D)             (None, 1, 1, 48)     55344       ['reshape_16[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 1, 1, 1152)   56448       ['conv2d_66[0][0]']
#
#  multiply_16 (Multiply)         (None, 4, 4, 1152)   0           ['activation_34[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 4, 4, 320)    368640      ['multiply_16[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 4, 4, 320)   1280        ['conv2d_68[0][0]']
#  ormalization)
#
#  conv2d_69 (Conv2D)             (None, 4, 4, 640)    204800      ['batch_normalization_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 4, 4, 640)   2560        ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 4, 4, 640)    0           ['batch_normalization_52[0][0]']
#
#  global_average_pooling2d_17 (G  (None, 640)         0           ['activation_35[0][0]']
#  lobalAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            2564        ['global_average_pooling2d_17[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 3,741,740
# Trainable params: 3,701,068
# Non-trainable params: 40,672
# __________________________________________________________________________________________________

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=hyperparameters['batch_size'],
    epochs=hyperparameters['epochs'],
    callbacks=[checkpoint, tensorboard_callback, early_stopping]
)
# Out:
# Epoch 1/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.3790 - accuracy: 0.8212
# Epoch 1: val_accuracy improved from -inf to 0.76982, saving model to best_lite_effnet.h5.keras
# 4516/4516 [==============================] - 148s 30ms/step - loss: 0.3789 - accuracy: 0.8213 - val_loss: 0.7373 - val_accuracy: 0.7698
# Epoch 2/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.2483 - accuracy: 0.8625
# Epoch 2: val_accuracy improved from 0.76982 to 0.85241, saving model to best_lite_effnet.h5.keras
# 4516/4516 [==============================] - 121s 27ms/step - loss: 0.2483 - accuracy: 0.8625 - val_loss: 0.2797 - val_accuracy: 0.8524
# Epoch 3/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.2176 - accuracy: 0.8735
# Epoch 3: val_accuracy did not improve from 0.85241
# 4516/4516 [==============================] - 120s 26ms/step - loss: 0.2176 - accuracy: 0.8735 - val_loss: 0.4364 - val_accuracy: 0.8428
# Epoch 4/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.2017 - accuracy: 0.8796
# Epoch 4: val_accuracy improved from 0.85241 to 0.87777, saving model to best_lite_effnet.h5.keras
# 4516/4516 [==============================] - 122s 27ms/step - loss: 0.2017 - accuracy: 0.8796 - val_loss: 0.1914 - val_accuracy: 0.8778
# Epoch 5/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.8799
# Epoch 5: val_accuracy improved from 0.87777 to 0.89438, saving model to best_lite_effnet.h5.keras
# 4516/4516 [==============================] - 121s 27ms/step - loss: 0.1934 - accuracy: 0.8800 - val_loss: 0.1745 - val_accuracy: 0.8944
# Epoch 6/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.8816
# Epoch 6: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 119s 26ms/step - loss: 0.1904 - accuracy: 0.8816 - val_loss: 0.1826 - val_accuracy: 0.8818
# Epoch 7/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.8841
# Epoch 7: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 119s 26ms/step - loss: 0.1851 - accuracy: 0.8841 - val_loss: 1.3856 - val_accuracy: 0.5905
# Epoch 8/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.8854
# Epoch 8: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 118s 26ms/step - loss: 0.1845 - accuracy: 0.8854 - val_loss: 0.4167 - val_accuracy: 0.8141
# Epoch 9/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.8848
# Epoch 9: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 120s 27ms/step - loss: 0.1826 - accuracy: 0.8848 - val_loss: 0.1774 - val_accuracy: 0.8882
# Epoch 10/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.8850
# Epoch 10: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 114s 25ms/step - loss: 0.1821 - accuracy: 0.8850 - val_loss: 0.1761 - val_accuracy: 0.8853
# Epoch 11/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1772 - accuracy: 0.8888
# Epoch 11: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 116s 26ms/step - loss: 0.1772 - accuracy: 0.8888 - val_loss: 0.1873 - val_accuracy: 0.8842
# Epoch 12/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1753 - accuracy: 0.8867
# Epoch 12: val_accuracy did not improve from 0.89438
# 4516/4516 [==============================] - 167s 37ms/step - loss: 0.1753 - accuracy: 0.8867 - val_loss: 0.1882 - val_accuracy: 0.8781
# Epoch 13/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.8880
# Epoch 13: val_accuracy did not improve from 0.89438
# Restoring model weights from the end of the best epoch: 5.
# 4516/4516 [==============================] - 122s 27ms/step - loss: 0.1773 - accuracy: 0.8881 - val_loss: 0.1829 - val_accuracy: 0.8840
# Epoch 13: early stopping

# %%
# Load the best model
best_model = models.load_model('best_lite_effnet_tuned.h5.keras')

# Evaluate the model
val_loss, best_val_acc = best_model.evaluate(X_valid, y_valid, verbose=2)
print("\nLite EfficientNet Validation Accuracy:", best_val_acc)

# Generate predictions
val_predictions = best_model.predict(X_valid)
val_predicted_classes = np.argmax(val_predictions, axis=1)

# Confusion matrix
cm = confusion_matrix(y_valid, val_predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', 
            xticklabels=ship_categories.values(), 
            yticklabels=ship_categories.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Lite EfficientNet Confusion Matrix')
plt.show()
# Out:
# 283/283 - 4s - loss: 0.1858 - accuracy: 0.8893 - 4s/epoch - 13ms/step
#
# Lite EfficientNet Validation Accuracy: 0.8892825245857239
# 283/283 [==============================] - 3s 12ms/step

# %%
# Path to test images and labels
test_img_dir = "C:/Users/matko/Desktop/data_h_c_s_a/train_v3/test"
test_csv_path = "C:/Users/matko/Desktop/data_h_c_s_a/train_v3/test.csv"

# Load test image names and labels
test_img_names = os.listdir(test_img_dir)
test_df = pd.read_csv(test_csv_path)
test_df["Actual Class Index"] = test_df["category"] - 1  # zero-based

# Load and preprocess ALL test images
all_test_images = []
for img_name in test_img_names:
    img_path = os.path.join(test_img_dir, img_name)
    img = tf.keras.utils.load_img(img_path, target_size=hyperparameters['image_size'], color_mode='grayscale')
    imgarr = tf.keras.utils.img_to_array(img) / 255.0
    all_test_images.append(imgarr)
all_test_images = np.asarray(all_test_images)

# Predict classes for all test images
all_test_preds = best_model.predict(all_test_images)
all_test_pred_classes = np.argmax(all_test_preds, axis=1)

# Prepare actual class indices in the same order as test_img_names
actual_class_map = dict(zip(test_df["image"], test_df["Actual Class Index"]))
all_actual_class_indices = [actual_class_map[img] for img in test_img_names]

# Calculate test accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
test_accuracy = accuracy_score(all_actual_class_indices, all_test_pred_classes)
print(f"Test accuracy: {test_accuracy:.4f}")

# Plot confusion matrix for the whole test set
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_actual_class_indices, all_test_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', 
            xticklabels=ship_categories.values(), 
            yticklabels=ship_categories.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix on Whole Test Set')
plt.show()
# Out:
# 43/43 [==============================] - 1s 22ms/step
# Test accuracy: 0.7933
