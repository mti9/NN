# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.math import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense
import keras_tuner as kt
import os
import random
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Define hyperparameters
hyperparameters = {
    'learning_rate': 0.001,
    'batch_size': 8,
    'epochs': 50,
    'optimizer': 'adam',
    'loss_function': 'sparse_categorical_crossentropy',
    'image_size': (128, 128),
    'num_classes': 4,
    'data_augmentation': True,
}

# TensorBoard Logging
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# Create the TensorBoard callback
tensorboard_callback = TensorBoard(
    log_dir=log_dir,
    histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
)

# %%
# --- UPDATED PATHS ---
train_csv_path = "C:/Users/matko/Desktop/data_h_c_s_a/spectograms/train.csv"
train_img_dir = "C:/Users/matko/Desktop/data_h_c_s_a/spectograms/train"

# Load the dataset
train = pd.read_csv(train_csv_path)

# Split into train and validation sets
train, valid = train_test_split(
    train,
    test_size=0.2,         # 20% for validation
    stratify=train["category"],  # keep class distribution
    random_state=42
)

# %%
# Check the shape of the dataset
print("Train shape:", train.shape)
print("Valid shape:", valid.shape)

# Plot the distribution of ship categories
ship_categories = {0: 'Synthetize', 1: 'Annonymise', 2: 'Cloned', 3: 'Human'}
sns.countplot(x=train["category"].map(ship_categories))
plt.title("Distribution of Sound Categories (Train)")
plt.show()

sns.countplot(x=valid["category"].map(ship_categories))
plt.title("Distribution of Sound Categories (Valid)")
plt.show()
# Out:
# Train shape: (36128, 2)
# Valid shape: (9032, 2)

# %%
def load_and_preprocess_images(df, img_dir):
    images = []
    for img_name in df["image"]:  # Use the correct column name for image filenames
        img_path = os.path.join(img_dir, img_name)
        img = tf.keras.utils.load_img(img_path, color_mode='grayscale')  # No target_size needed
        imgarr = tf.keras.utils.img_to_array(img) / 255.0
        images.append(imgarr)
    return np.asarray(images)

# Prepare data
X_train = load_and_preprocess_images(train, train_img_dir)
X_valid = load_and_preprocess_images(valid, train_img_dir)

# %%
# Plot the first 20 resized images from train set
nrow = 5
ncol = 4
fig1 = plt.figure(figsize=(15, 15))
fig1.suptitle('First 20 Train Images After Resizing', size=32)
for i in range(20):
    plt.subplot(nrow, ncol, i + 1)
    plt.imshow(X_train[i])
    class_num = train["category"].iloc[i]  # <-- poprawka: iloc zamiast []
    plt.title(f'class = {class_num}, Ship is {ship_categories[class_num]}')
    plt.axis('off')
    plt.grid(False)
plt.show()

# %%
def resnet_block(x, filters, kernel_size=3, stride=1):
    shortcut = x
    x = Conv2D(filters, kernel_size, strides=stride, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size, strides=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, 1, strides=stride, padding='same', use_bias=False)(shortcut)
        shortcut = BatchNormalization()(shortcut)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

inputs = Input(shape=(*hyperparameters['image_size'], 1))
x = Conv2D(16, 3, strides=1, padding='same', use_bias=False)(inputs)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 3 residual blocks (2 conv layers each) = 6 conv layers
x = resnet_block(x, 16)
x = resnet_block(x, 16)
x = resnet_block(x, 32, stride=2)
x = resnet_block(x, 32)
x = resnet_block(x, 64, stride=2)
x = resnet_block(x, 64)

x = GlobalAveragePooling2D()(x)
outputs = Dense(hyperparameters['num_classes'], activation='softmax')(x)

model = Model(inputs, outputs)

model.compile(
    optimizer=hyperparameters['optimizer'],
    loss=hyperparameters['loss_function'],
    metrics=['accuracy']
)

# ModelCheckpoint Callback
checkpoint = ModelCheckpoint('best_model.h5.keras', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# EarlyStopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=8,           # Stop after 8 epochs with no improvement
    restore_best_weights=True,
    verbose=1
)

# %%
def build_model(hp):
    inputs = Input(shape=(*hyperparameters['image_size'], 1))
    x = Conv2D(
        filters=hp.Choice('filters', [16, 32, 64]),
        kernel_size=3,
        strides=1,
        padding='same',
        use_bias=False
    )(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Przykładowa liczba bloków residualnych
    for i in range(hp.Int('num_blocks', 2, 4)):
        x = resnet_block(
            x,
            filters=hp.Choice(f'block_{i}_filters', [16, 32, 64]),
            kernel_size=3,
            stride=1
        )

    x = GlobalAveragePooling2D()(x)
    x = Dense(
        hp.Int('dense_units', 32, 128, step=32),
        activation='relu'
    )(x)
    outputs = Dense(hyperparameters['num_classes'], activation='softmax')(x)
    model = Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')
        ),
        loss=hyperparameters['loss_function'],
        metrics=['accuracy']
    )
    return model

# %%
# Initialize the Keras Tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='tuner_dir',
    project_name='spectrogram_tuning'
)

# %%
# Przygotuj y_train, y_valid jeśli jeszcze nie są przygotowane
y_train = train["category"]
y_valid = valid["category"]

# %%
tuner.search(
    X_train, y_train,
    epochs=10,
    validation_data=(X_valid, y_valid),
    callbacks=[early_stopping],
    verbose=2
)

# %%
# Reload the tuner from the directory
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='C:/Users/matko/Desktop/data_h_c_s_a/spectograms/tuner_dir',
    project_name='spectrogram_tuning'
)
tuner.reload()

# Get all trial IDs (as keys of the trials dict)
all_trial_ids = list(tuner.oracle.trials.keys())

# Get the last trial's ID and object
last_trial_id = all_trial_ids[-1]
last_trial = tuner.oracle.trials[last_trial_id]

# Extract hyperparameters from the last trial
best_hps = tuner.get_best_hyperparameters(1)[0]
print("Najlepsze hiperparametry:", best_hps.values)
# Out:
# Reloading Tuner from C:/Users/matko/Desktop/data_h_c_s_a/spectograms/tuner_dir\spectrogram_tuning\tuner0.json
# Najlepsze hiperparametry: {'filters': 16, 'num_blocks': 3, 'block_0_filters': 32, 'block_1_filters': 32, 'dense_units': 32, 'learning_rate': 0.00021893220837161223, 'block_2_filters': 16, 'block_3_filters': 16}

# %%
# Limit GPU memory growth to prevent allocation errors
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# Physical devices cannot be modified after being initialized

# %%
# Zbuduj i trenuj model z najlepszymi hiperparametrami
model_best = tuner.hypermodel.build(best_hps)
history_best = model_best.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=best_hps.values.get('batch_size', hyperparameters['batch_size']),
    epochs=hyperparameters['epochs'],
    callbacks=[checkpoint, tensorboard_callback, early_stopping],
)
# Out:
# Epoch 1/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.4546 - accuracy: 0.8131
# Epoch 1: val_accuracy improved from -inf to 0.87356, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 123s 25ms/step - loss: 0.4546 - accuracy: 0.8131 - val_loss: 0.2699 - val_accuracy: 0.8736
# Epoch 2/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.8720
# Epoch 2: val_accuracy did not improve from 0.87356
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.2533 - accuracy: 0.8720 - val_loss: 0.6287 - val_accuracy: 0.7034
# Epoch 3/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.2285 - accuracy: 0.8755
# Epoch 3: val_accuracy improved from 0.87356 to 0.87998, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.2285 - accuracy: 0.8755 - val_loss: 0.2072 - val_accuracy: 0.8800
# Epoch 4/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.2129 - accuracy: 0.8801
# Epoch 4: val_accuracy did not improve from 0.87998
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.2128 - accuracy: 0.8801 - val_loss: 1.1719 - val_accuracy: 0.6411
# Epoch 5/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.8815
# Epoch 5: val_accuracy did not improve from 0.87998
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.2043 - accuracy: 0.8815 - val_loss: 0.2836 - val_accuracy: 0.8468
# Epoch 6/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.8825
# Epoch 6: val_accuracy did not improve from 0.87998
# 4516/4516 [==============================] - 112s 25ms/step - loss: 0.1982 - accuracy: 0.8825 - val_loss: 3.1298 - val_accuracy: 0.5441
# Epoch 7/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1956 - accuracy: 0.8851
# Epoch 7: val_accuracy did not improve from 0.87998
# 4516/4516 [==============================] - 110s 24ms/step - loss: 0.1956 - accuracy: 0.8851 - val_loss: 1.0000 - val_accuracy: 0.6622
# Epoch 8/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1908 - accuracy: 0.8844
# Epoch 8: val_accuracy did not improve from 0.87998
# 4516/4516 [==============================] - 112s 25ms/step - loss: 0.1908 - accuracy: 0.8844 - val_loss: 0.3392 - val_accuracy: 0.8446
# Epoch 9/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.8854
# Epoch 9: val_accuracy improved from 0.87998 to 0.88275, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1876 - accuracy: 0.8854 - val_loss: 0.1936 - val_accuracy: 0.8828
# Epoch 10/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.8878
# Epoch 10: val_accuracy improved from 0.88275 to 0.88585, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1859 - accuracy: 0.8878 - val_loss: 0.1844 - val_accuracy: 0.8859
# Epoch 11/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1836 - accuracy: 0.8863
# Epoch 11: val_accuracy did not improve from 0.88585
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1835 - accuracy: 0.8863 - val_loss: 0.4658 - val_accuracy: 0.7993
# Epoch 12/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1815 - accuracy: 0.8874
# Epoch 12: val_accuracy did not improve from 0.88585
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1815 - accuracy: 0.8874 - val_loss: 0.2376 - val_accuracy: 0.8806
# Epoch 13/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.8866
# Epoch 13: val_accuracy did not improve from 0.88585
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1794 - accuracy: 0.8866 - val_loss: 1.9695 - val_accuracy: 0.6141
# Epoch 14/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.8864
# Epoch 14: val_accuracy did not improve from 0.88585
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1797 - accuracy: 0.8864 - val_loss: 1.3154 - val_accuracy: 0.6723
# Epoch 15/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.8880
# Epoch 15: val_accuracy did not improve from 0.88585
# 4516/4516 [==============================] - 112s 25ms/step - loss: 0.1769 - accuracy: 0.8880 - val_loss: 0.8705 - val_accuracy: 0.7910
# Epoch 16/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1757 - accuracy: 0.8901
# Epoch 16: val_accuracy improved from 0.88585 to 0.88629, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1757 - accuracy: 0.8901 - val_loss: 0.1799 - val_accuracy: 0.8863
# Epoch 17/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1743 - accuracy: 0.8905
# Epoch 17: val_accuracy improved from 0.88629 to 0.88640, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 110s 24ms/step - loss: 0.1743 - accuracy: 0.8905 - val_loss: 0.1766 - val_accuracy: 0.8864
# Epoch 18/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1749 - accuracy: 0.8901
# Epoch 18: val_accuracy did not improve from 0.88640
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1748 - accuracy: 0.8901 - val_loss: 0.6798 - val_accuracy: 0.7455
# Epoch 19/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1735 - accuracy: 0.8898
# Epoch 19: val_accuracy improved from 0.88640 to 0.88851, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1735 - accuracy: 0.8898 - val_loss: 0.1775 - val_accuracy: 0.8885
# Epoch 20/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1732 - accuracy: 0.8885
# Epoch 20: val_accuracy improved from 0.88851 to 0.88939, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1733 - accuracy: 0.8884 - val_loss: 0.1866 - val_accuracy: 0.8894
# Epoch 21/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1716 - accuracy: 0.8926
# Epoch 21: val_accuracy did not improve from 0.88939
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1716 - accuracy: 0.8927 - val_loss: 0.1782 - val_accuracy: 0.8868
# Epoch 22/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1716 - accuracy: 0.8899
# Epoch 22: val_accuracy improved from 0.88939 to 0.89150, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1716 - accuracy: 0.8900 - val_loss: 0.1745 - val_accuracy: 0.8915
# Epoch 23/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1709 - accuracy: 0.8902
# Epoch 23: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1709 - accuracy: 0.8903 - val_loss: 0.1693 - val_accuracy: 0.8912
# Epoch 24/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.8892
# Epoch 24: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1707 - accuracy: 0.8892 - val_loss: 0.2063 - val_accuracy: 0.8876
# Epoch 25/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1697 - accuracy: 0.8917
# Epoch 25: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1697 - accuracy: 0.8917 - val_loss: 0.1713 - val_accuracy: 0.8897
# Epoch 26/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1701 - accuracy: 0.8913
# Epoch 26: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 108s 24ms/step - loss: 0.1701 - accuracy: 0.8914 - val_loss: 0.2066 - val_accuracy: 0.8803
# Epoch 27/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1685 - accuracy: 0.8893
# Epoch 27: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 109s 24ms/step - loss: 0.1685 - accuracy: 0.8893 - val_loss: 1.0238 - val_accuracy: 0.6609
# Epoch 28/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1690 - accuracy: 0.8919
# Epoch 28: val_accuracy did not improve from 0.89150
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1689 - accuracy: 0.8919 - val_loss: 3.4894 - val_accuracy: 0.5979
# Epoch 29/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.8903
# Epoch 29: val_accuracy improved from 0.89150 to 0.89216, saving model to best_model.h5.keras
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1677 - accuracy: 0.8903 - val_loss: 0.1692 - val_accuracy: 0.8922
# Epoch 30/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1680 - accuracy: 0.8898
# Epoch 30: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1679 - accuracy: 0.8898 - val_loss: 0.2068 - val_accuracy: 0.8815
# Epoch 31/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.8893
# Epoch 31: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1671 - accuracy: 0.8893 - val_loss: 1.5422 - val_accuracy: 0.6272
# Epoch 32/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.8924
# Epoch 32: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 113s 25ms/step - loss: 0.1669 - accuracy: 0.8924 - val_loss: 0.2100 - val_accuracy: 0.8783
# Epoch 33/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1658 - accuracy: 0.8921
# Epoch 33: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 112s 25ms/step - loss: 0.1658 - accuracy: 0.8920 - val_loss: 0.4368 - val_accuracy: 0.7941
# Epoch 34/50
# 4514/4516 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.8915
# Epoch 34: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 112s 25ms/step - loss: 0.1649 - accuracy: 0.8916 - val_loss: 5.5000 - val_accuracy: 0.5455
# Epoch 35/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1653 - accuracy: 0.8915
# Epoch 35: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 118s 26ms/step - loss: 0.1653 - accuracy: 0.8915 - val_loss: 0.3704 - val_accuracy: 0.8064
# Epoch 36/50
# 4516/4516 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.8934
# Epoch 36: val_accuracy did not improve from 0.89216
# 4516/4516 [==============================] - 118s 26ms/step - loss: 0.1653 - accuracy: 0.8934 - val_loss: 0.5918 - val_accuracy: 0.7059
# Epoch 37/50
# 4515/4516 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.8915
# Epoch 37: val_accuracy did not improve from 0.89216
# Restoring model weights from the end of the best epoch: 29.
# 4516/4516 [==============================] - 114s 25ms/step - loss: 0.1650 - accuracy: 0.8915 - val_loss: 1.8402 - val_accuracy: 0.7343
# Epoch 37: early stopping

# %%
# Load the best model saved during training
best_model = models.load_model('best_model.h5.keras')

# Evaluate the best model on the validation set
val_loss, best_val_acc = best_model.evaluate(X_valid, y_valid, verbose=2)
print("\nBest Validation Accuracy:", best_val_acc)

# Predict classes for the validation set
val_predictions = best_model.predict(X_valid)
val_predicted_classes = np.argmax(val_predictions, axis=1)

# Calculate mean accuracy
mean_accuracy = accuracy_score(y_valid, val_predicted_classes)
print("Mean accuracy on the whole validation set:", mean_accuracy)
# Out:
# 283/283 - 8s - loss: 0.1692 - accuracy: 0.8925 - 8s/epoch - 29ms/step
#
# Best Validation Accuracy: 0.8924933671951294
# 283/283 [==============================] - 8s 27ms/step
# Mean accuracy on the whole validation set: 0.8924933569530558

# %%
# Generate predictions
best_predictions = best_model.predict(X_valid)
best_predicted_classes = np.argmax(best_predictions, axis=1)

# Plot the confusion matrix
best_cm = confusion_matrix(y_valid, best_predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(best_cm, annot=True, fmt='g', cmap='Blues', xticklabels=ship_categories.values(), yticklabels=ship_categories.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# 283/283 [==============================] - 8s 27ms/step

# %%
# Plot the first 20 predictions
plt.figure(figsize=(15, 15))
plt.suptitle('First 20 Predicted Images with Predicted Classes', size=20)
for i in range(20):
    plt.subplot(5, 4, i + 1)
    plt.imshow(X_valid[i])
    predicted_class_label = ship_categories[best_predicted_classes[i]]
    actual_class_label = ship_categories[y_valid.iloc[i]]

    if best_predicted_classes[i] == y_valid.iloc[i]:
        title_color = 'green'
    else:
        title_color = 'red'

    title = f'Predicted Class: {predicted_class_label}\nActual Class: {actual_class_label}'
    plt.title(title, color=title_color)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Path to test images and labels
test_img_dir = "C:/Users/matko/Desktop/data_h_c_s_a/train_v3/test"
test_csv_path = "C:/Users/matko/Desktop/data_h_c_s_a/train_v3/test.csv"

# Load test image names and labels
test_img_names = os.listdir(test_img_dir)
test_df = pd.read_csv(test_csv_path)
test_df["Actual Class Index"] = test_df["category"] - 1  # zero-based

# Load and preprocess ALL test images
all_test_images = []
for img_name in test_img_names:
    img_path = os.path.join(test_img_dir, img_name)
    img = tf.keras.utils.load_img(img_path, target_size=hyperparameters['image_size'], color_mode='grayscale')
    imgarr = tf.keras.utils.img_to_array(img) / 255.0
    all_test_images.append(imgarr)
all_test_images = np.asarray(all_test_images)

# Predict classes for all test images
all_test_preds = best_model.predict(all_test_images)
all_test_pred_classes = np.argmax(all_test_preds, axis=1)

# Prepare actual class indices in the same order as test_img_names
actual_class_map = dict(zip(test_df["image"], test_df["Actual Class Index"]))
all_actual_class_indices = [actual_class_map[img] for img in test_img_names]

# Calculate test accuracy
from sklearn.metrics import confusion_matrix, accuracy_score
test_accuracy = accuracy_score(all_actual_class_indices, all_test_pred_classes)
print(f"Test accuracy: {test_accuracy:.4f}")

# Plot confusion matrix for the whole test set
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_actual_class_indices, all_test_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', 
            xticklabels=ship_categories.values(), 
            yticklabels=ship_categories.values())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix on Whole Test Set')
plt.show()
# Out:
# 43/43 [==============================] - 1s 30ms/step
# Test accuracy: 0.9633
